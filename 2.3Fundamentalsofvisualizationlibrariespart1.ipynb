# %% [markdown]
# ## E3 Fundamentals of Visualization libraries Part 1 ß Matplotlib

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.9.2'

# %% [markdown]
# ### Read in the dataset

# %%
df = pd.read_csv('NewYork_data.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', '_merge'],
#       dtype='object')

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual        date  avgTemp
# 0 -74.040041  40.736982 -74.027781        casual  2022-03-18     13.9
# 1 -74.064194  40.719586 -74.043117        member  2022-03-04     -1.9
# 2 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 3 -74.064194  40.719586 -74.043117        member  2022-03-13     -2.3
# 4 -74.064194  40.719586 -74.043117        member  2022-03-11      7.2

# %%
df.shape
# Out:
# (1388898, 15)

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# started_at                    object
# ended_at                      object
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# avgTemp                      float64
# dtype: object

# %% [markdown]
# ### Plotting with pandas

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-03-18  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17
# 2022-03-04  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48
# 2022-03-13  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32
# 2022-03-13  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47
# 2022-03-11  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18
#
#                        ended_at                      start_station_name  \
# date
# 2022-03-18  2022-03-18 15:45:34  Mama Johnson Field - 4 St & Jackson St
# 2022-03-04  2022-03-04 16:50:45                   Baldwin at Montgomery
# 2022-03-13  2022-03-13 17:54:44                   Baldwin at Montgomery
# 2022-03-13  2022-03-13 15:41:22                   Baldwin at Montgomery
# 2022-03-11  2022-03-11 12:33:24                   Baldwin at Montgomery
#
#            start_station_id                              end_station_name  \
# date
# 2022-03-18            HB404  South Waterfront Walkway - Sinatra Dr & 1 St
# 2022-03-04            JC020                                 Grove St PATH
# 2022-03-13            JC020                                 Grove St PATH
# 2022-03-13            JC020                                 Grove St PATH
# 2022-03-11            JC020                                 Grove St PATH
#
#            end_station_id  start_lat  start_lng    end_lat    end_lng  \
# date
# 2022-03-18          HB103  40.743140 -74.040041  40.736982 -74.027781
# 2022-03-04          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-13          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-13          JC005  40.723659 -74.064194  40.719586 -74.043117
# 2022-03-11          JC005  40.723659 -74.064194  40.719586 -74.043117
#
#            member_casual  avgTemp
# date
# 2022-03-18        casual     13.9
# 2022-03-04        member     -1.9
# 2022-03-13        member     -2.3
# 2022-03-13        member     -2.3
# 2022-03-11        member      7.2

# %%
df_temp['avgTemp'].plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Procedural approach

# %%
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.title('Temperatures daily for 2022')
plt.plot(df_temp['avgTemp'])
plt.show()

# %%
plt.title('Temperatures daily for 2022')
plt.figure(figsize=(10,4))
plt.plot(df_temp['avgTemp'])
plt.show()

# %% [markdown]
# ### Aggregrate rides

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp'],
#       dtype='object')

# %%
# Groupby the count of the trips 

df_group = pd.DataFrame(df.groupby(['date'])['ride_id'].count()).reset_index()

# %%
df_group.head()
# Out:
#         date  ride_id
# 0 2021-06-01     2024
# 1 2021-06-02     1956
# 2 2021-06-03     1285
# 3 2021-06-04     1693
# 4 2021-06-05     2771

# %%
df_group.rename(columns = {'ride_id':'bike_rides_daily'}, inplace = True)
df = df.merge(df_group, on = "date", how = 'outer', indicator = True)
print(df['_merge'].value_counts(dropna = False))
print("Shape of January 1st is", df[df['date'] == '2021-06-01'].shape) # Check 
print("Shape of January 2nd is", df[df['date'] == '2021-06-02'].shape) # Second check 

df_temp = df.set_index('date')

print(df_temp.columns)
# Out:
# _merge
# both          1388898
# left_only           0
# right_only          0
# Name: count, dtype: int64
# Shape of January 1st is (2024, 17)
# Shape of January 2nd is (1956, 17)
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'avgTemp', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2021-06-01  BC3FFFD55572712C    docked_bike  2021-06-01 20:38:35
# 2021-06-01  76244D3FB84245AA    docked_bike  2021-06-01 16:42:40
# 2021-06-01  A284AABB2C747554  electric_bike  2021-06-01 17:06:54
# 2021-06-01  88CCB07E62CA4AFA    docked_bike  2021-06-01 17:58:56
# 2021-06-01  42B65D476BD5FE41  electric_bike  2021-06-01 11:22:54
#
#                        ended_at     start_station_name start_station_id  \
# date
# 2021-06-01  2021-06-01 20:42:31  11 St & Washington St            HB502
# 2021-06-01  2021-06-01 16:46:28   8 St & Washington St            HB603
# 2021-06-01  2021-06-01 17:19:07  11 St & Washington St            HB502
# 2021-06-01  2021-06-01 18:06:52  11 St & Washington St            HB502
# 2021-06-01  2021-06-01 11:28:52  11 St & Washington St            HB502
#
#                                    end_station_name end_station_id  start_lat  \
# date
# 2021-06-01        Columbus Park - Clinton St & 9 St          HB501  40.749984
# 2021-06-01        Columbus Park - Clinton St & 9 St          HB501  40.745983
# 2021-06-01  Hoboken Terminal - River St & Hudson Pl          HB102  40.749984
# 2021-06-01  Hoboken Terminal - River St & Hudson Pl          HB102  40.749984
# 2021-06-01  Hoboken Terminal - River St & Hudson Pl          HB102  40.749984
#
#             start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2021-06-01 -74.027150  40.748161 -74.032453        member      NaN
# 2021-06-01 -74.028199  40.748161 -74.032453        member      NaN
# 2021-06-01 -74.027150  40.736068 -74.029127        casual      NaN
# 2021-06-01 -74.027150  40.736068 -74.029127        member      NaN
# 2021-06-01 -74.027150  40.736068 -74.029127        member      NaN
#
#             bike_rides_daily _merge
# date
# 2021-06-01              2024   both
# 2021-06-01              2024   both
# 2021-06-01              2024   both
# 2021-06-01              2024   both
# 2021-06-01              2024   both

# %%
plt.figure(figsize=(10,5))
plt.title('Temperature per trips')
plt.plot(df_temp['avgTemp'])
plt.plot(df_temp['bike_rides_daily'], color = 'red')
plt.show()

# %% [markdown]
# ### OO Approach

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")
ax.plot(df_temp['avgTemp'], color = 'blue')

# %%
# Create figure and axis objects with subplots()

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "red")

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "blue")
plt.show()

# %% [markdown]
# ### Final Dual Plot

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(figsize=(10, 5))

# Make a plot of the bike rides
ax.plot(df_temp['bike_rides_daily'],color = "navy")
ax.set_xlabel("Year 2022", fontsize = 14) # set x-axis label
ax.set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Here is where we create the dual axis - initialize a twin object for two different y-axis on the sample plot
ax2 = ax.twinx()

# Make a plot with the temperatues on the y-axis using second axis object
ax2.plot(df_temp["avgTemp"], color = "red")
ax2.set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.title('Temperature and trips in 2022', fontsize = 18)
plt.show()

# %% [markdown]
# ## Matplotlib Line Plots with Twin Axes
# - To create a line plot with twin axes, we need to use the twinx() function.
# - This function creates a new y-axis that shares the same x-axis as the original plot.
# - We can see on the X-axis, the year 2022 acts as a common axis for temperatues and bike rides daily.
# - To represent two variables with different scales on the same plot, using twin axes is an effective way to visualize the relationship between the variables without losing the clarity of the individual scales.

# %%
plt.style.use('ggplot')

# %%
# Create figure and axis objects with subplots() and details

fig,ax = plt.subplots(2, figsize =(8, 6))

# Make a plot of the bike rides
ax[0].plot(df_temp['bike_rides_daily'],color = "navy")
ax[0].set_ylabel("Bike rides daily",color = "navy", fontsize = 14) # set y-axis label

# Make a plot with the temperatues on the y-axis using second axis object
ax[1].plot(df_temp["avgTemp"], color = "red")
ax[1].set_ylabel("Average temperatures", color = "red",fontsize=14)
plt.suptitle('Temperature and trips in 2022', fontsize = 18)

plt.show()

# %%
# save the plot as a file
fig.savefig('trips_temperatures_dual_line.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## END
